# %% [markdown]
# ## 半正定规划（semi-definite programming）的求解算法介绍
#
# 写作这一篇notebook的主要动机有以下两点：
# * 通过具体代码实现来深入理解SDP问题求解算法的基本原理；
# * 对已有求解器在实际求解中的好用程度进行评估选择。对求解器的计算效率比较可以参考[Hans Mittlemann教授的benchmarking](http://plato.asu.edu/ftp/sparse_sdp.html)；但是在实际使用过程中，API的清晰程度、与其他工具包交互的难易程度、问题数据读写的效率等因素也很重要。
#
# 首先，我们进行一些准备工作：从[这个网址](http://euler.nmt.edu/~brian/sdplib/)中获取SDPLIB测试案例，用于后续对求解器的评估测试。

# %%
import glob

fnames = sorted(glob.glob('sdplib/*.dat-s'))
print(len(fnames))
# Out:
# 92

# %% [markdown]
# ### SDP问题定义
#
# 原始问题
# $$
# \begin{equation}\label{eq:P}
#     \begin{aligned}
#         \max \ & C(X) \\
#         s.t. \ & A(X) = b \\
#              \ & X \succeq 0
#     \end{aligned} \tag{P}
# \end{equation}
# $$
#
# 其中$A(X) = [\text{tr}(A_1X),\cdots,\text{tr}(A_nX)]^T$；其对偶问题为
#
# $$
# \begin{equation}\label{eq:D}
#     \begin{aligned}
#         \min \ & b^Ty \\
#         s.t. \ & A^T(y) \succeq C \\
#     \end{aligned} \tag{D}
# \end{equation}
# $$
#
# 其中$A^T(y) = \sum_{i=1}^n y_i A_i$。

# %% [markdown]
# ### 调用已有求解器
#
# 首先，我们介绍一些已有求解器的使用方法。这里，我们主要介绍三种求解器：
#
# 1. [CSDP](https://github.com/coin-or/Csdp)：用C语言实现的SDP求解器。
#     * 安装：从[git repo](https://github.com/coin-or/Csdp)中获取源代码，然后根据本地机器的配置修改makefile，手动编译。
#     * 使用：需要通过命令行执行；Python可以通过subprocess进行调用。一个缺点是对于Python脚本产生的问题数据，需要先写成一个数据文件、然后再调用CSDP，存在IO上的增量计算开销。这在需要resolve的场景中不是很友好。
# 2. [CVXOPT](https://github.com/cvxopt/cvxopt)：面向Python的通用凸优化求解器，对不同类型的凸优化问题提供了一套统一的建模和求解接口。
#     * 安装：可以直接pip install安装。
#     * 使用：自身提供的API可以直接处理内存中的问题数据；如果是数据文件，则需要手动读取或者使用smcp提供的读取函数。
# 3. [smcp](https://github.com/cvxopt/smcp)：用C和Python实现的SDP求解器，是CVXOPT项目的一部分。
#     * 安装：可以直接pip install安装。
#     * 使用：自身提供的API可以处理数据文件或是内存中的问题数据。
#
# 下面的代码块将通过SDPLIB中的测试案例，对上述求解器的求解正确性和计算效率进行评估比较。

# %%
import smcp
import subprocess
from IPython.utils import io
import time
import numpy as np

INF = 1e20

for fname in fnames:
    if 'G' not in fname:
        model_name = fname.split('.')[0].split('/')[1]
        out_fname = 'outputs/{}.out'.format(model_name)

        with io.capture_output() as captured:
            tt = time.time()
            ## csdp
            obj_csdp = -INF
            try:
                subprocess.call('csdp {} > {}'.format(fname,out_fname),
                               shell=True,stdout=subprocess.PIPE)
                with open(out_fname,'r+') as f:
                    lines = f.readlines()
                    for line in lines:
                        if 'Primal objective value:' in line:
                            obj_csdp = float(line[24:].strip())
                            break
            except Exception as e:
                print(e)
            time_csdp = time.time() - tt

            sdp = smcp.SDP(fname)
            tt = time.time()
            ## smcp
            obj_smcp = -INF
            try:
                sol_smcp = sdp.solve_esd()
                obj_smcp = -sol_smcp['primal_objective']
            except Exception as e:
                print(e)
            time_smcp = time.time() - tt

            tt = time.time()
            ## cvx
            obj_cvx = -INF
            try:
                sol_cvx = sdp.solve_cvxopt(options={'show_progress':False, 'maxiters':50})
                obj_cvx = sol_cvx['primal objective']
            except Exception as e:
                print(e)
            time_cvx = time.time() - tt
            
        print('elapsed time: csdp={:.2f}, smcp={:.2f}, cvx={:.2f}'.format(time_csdp,time_smcp,time_cvx))
        print('objectives: csdp={:.2f}, smcp={:.2f}, cvx={:.2f}'.format(obj_csdp,obj_smcp,obj_cvx))

# %% [markdown]
# 根据上面的结果可以看出，CSDP显著更快；这是由于CSDP是针对SDP问题而专门开发的求解器。CVXOPT则作为通用的凸优化求解器，计算效率较低。最后，smcp经常得不到正确结果，因此不建议使用。

# %% [markdown]
# ### 内点法的实现

# %% [markdown]
# 在这一小节中，我将实现一种基础的求解方法：引入罚函数的内点法。具体来说，我们可以在对偶问题中引入关于$S = C - A^T(y)$惩罚项，从而提高问题的光滑程度并降低求解难度：
# $$
# \begin{equation}\label{eq:DB}
#     \begin{aligned}
#         \min \ & b^Ty - \mu \log\det S \\
#         s.t. \ & A^T(y) = S + C \\
#              \ & S \succeq 0
#     \end{aligned} \tag{DB}
# \end{equation}
# $$
#
# 其中$\mu \geq 0$是一个超参数，当$\mu \to 0$时，上述问题的最优解趋于原对偶问题的最优解。上述问题的KKT条件为
# $$
# \begin{equation}\label{eq:KKT}
#     \begin{aligned}
#         \ & A(x) = b \\
#         \ & A^T(y) = S + C \\
#         \ & SX = \mu I \\
#         \ & X \succeq 0, S \succeq 0
#     \end{aligned} \tag{KKT}
# \end{equation}
# $$

# %% [markdown]
# 我们可以通过牛顿法来求解该KKT条件。具体来说，给定一个超参数$\mu$和一个初始解$(X,S,y)$（满足$X$和$S$是半正定的），上述KKT系统在该初始解的线性化形式为
# $$
# \begin{equation}\label{eq:KKT_linear}
#     \begin{aligned}
#         \ & A(X + \Delta X) = b \\
#         \ & A^T(y + \Delta y) = S + \Delta S + C \\
#         \ & SX + \Delta S X + S \Delta X = \mu I
#     \end{aligned} \tag{KKT linearization}
# \end{equation}
# $$
#
# 要求解该线性系统，首先，将第二个等式中$\Delta S$的形式代入第三个等式中，有
# $$
# \begin{equation}
#     \begin{aligned}
#         X + \Delta X & = - S^{-1} (\Delta S X - \mu I) \\
#         & = \tilde{C} - S^{-1} A^T(\Delta y) X \\
#     \end{aligned}
# \end{equation}
# $$
#
# 其中$\tilde{C} = - S^{-1} ((A^Ty - S - C) X - \mu I)$。然后，再将上述式子代入线性系统的第一个等式，有
# $$
# \begin{equation}
#     \begin{aligned}
#         A(\tilde{C}) - A(S^{-1} A^T(\Delta y) X) & = b \\
#     \end{aligned}
# \end{equation}
# $$
#
# 换句话说，如果我们令$O$为由元素$O_{ij} = \text{tr}(A_i S^{-1} A_j X)$组成的矩阵，那么上述等式可以写为
# $$
# \begin{equation}
#     O \Delta y = A(\tilde{C}) - b
# \end{equation}
# $$
#
# 此时，我们可以通过任意线性方程求解器来求解得到$\Delta y$。然后通过回代可以得到$\Delta X$和$\Delta S$。
#
# 最后，$X + \Delta X$或$S + \Delta S$有可能不是半正定的，这会导致迭代过程无法继续下去。因此我们需要寻找合适的步长$\alpha_p$和$\alpha_d$使得$X + \Delta X$或$S + \Delta S$都是半正定的。由于$X$和$S$是对称阵，因此可以通过找到$X^{-1/2}\Delta X X^{-1/2}$和$S^{-1/2}\Delta S S^{-1/2}$的最大特征值来设计步长。

# %% [markdown]
# 下面的代码块给出了上述算法的一个简单实现，其中一些辅助工作作为函数被封装在了util.py中：
# * process_inputs函数从数据文件中读取问题数据。它先使用smcp包中的sdpa_read函数对.dat-s文件(SDPA格式)进行读取，然后将问题输入数据转化为scipy的稀疏矩阵格式。
# * initialization函数根据问题输入$A,C,b$的结构初始化矩阵$X,S$。这里的实现参考了CSDP中的initsoln函数，但是没有利用矩阵$A,C$的分块特征。
# * line_search函数负责寻找合适的迭代步长。它首先根据矩阵$X$和增量$\Delta X$，尝试找到最大可行的步长$\alpha_{max} > 0$使得$X + \alpha \Delta X$是半正定的。如上所述，这可以转化为一个特征值求解问题。在找到最大可行步长$\alpha_{max}$后，令实际步长$\alpha$为$\alpha_{max}$的一定比例的折减（例如，$\alpha = 0.95 \alpha_{max}$），以使得更新后的矩阵$X + \alpha \Delta X$与半正定边界保持一定距离，不至于影响后续迭代的效率。

# %%
import time
import numpy as np
import scipy.sparse as sp
from scipy.sparse import csr_matrix,csc_matrix
import scipy.sparse.linalg as splinalg
import smcp
from sksparse.cholmod import cholesky,Factor
from util import *

def solve(fname,print_iter = 100):
    model_name = fname.split('.')[0].split('/')[1]
    
    ## load inputs
    n,m,C_csc,b_dense,As_h,As_csr,As_csc = process_inputs(fname,model_name)
    
    total_tt = time.time()
    
    ## initialization
    I = sp.eye(n,n,dtype=np.float64).tocsc()
    X,S = initialization(As_csc,C_csc,b_dense,n,m)
    y = np.zeros((m,))
    S_inv_op = cholesky(S)
    mu = np.sum((S.multiply(X)).data) / n / 2 ## tr(SX)
    
    iter_ = 0
    while iter_ < 10000 and (time.time() - total_tt) < 1200:
        iter_ += 1
        tt = time.time()
        
        ## compute objectives and errors in constraints
        obj_primal = np.sum((C_csc.multiply(X)).data) ## C(X)
        obj_dual = np.dot(b_dense,y) ## b^Ty
        ep_dual = csc_matrix(As_csc.dot(y).reshape((n,n))) - S - C_csc ## A^T(y) - S - C
        ep_primal = X.reshape((n*n,1)).T.dot(As_csc).A[0,:] - b_dense ## A(X) - b
        ep_comp = S.dot(X) - mu * I ## SX - \mu I
        err_primal = np.max(np.abs(ep_primal))
        if len(ep_dual.data) > 0:
            err_dual = np.max(np.abs(ep_dual.data))
        else:
            err_dual = 0
        if len(ep_comp.data) > 0:
            err_comp = np.max(np.abs(ep_comp.data))
        else:
            err_comp = 0
        if iter_ % print_iter == 0:
            print('iter={}. objp={:.3e}, objd={:.3e}, errp={:.3e}, errd={:.3e}, errcs={:.3e}'.format(
                iter_,obj_primal,obj_dual,err_primal,err_dual,err_comp))
            
        ## check for convergence
        is_converged = abs(obj_primal - obj_dual) < max(abs(obj_primal),abs(obj_dual),1) * TOL
        is_feas = (err_primal < TOL) and (err_dual < TOL)
        if is_converged and is_feas:
            break
            
        ## compute O
        SiAs_csc = S_inv_op.solve_A(As_h) ## S^{-1}A
        SiAs_csc = SiAs_csc.reshape((n*m,n))
        SiAXs_csc = SiAs_csc.dot(X) ## S^{-1}AX
        SiAXs_csc = SiAXs_csc.reshape((n,m*n))
        O = As_csr.dot(SiAXs_csc.reshape((n*n,m),order='F')).A
        
        ## compute v = A(C_tilde) - b
        C_tilde = -S_inv_op.solve_A(ep_dual.dot(X) - mu * I)
        v = (C_tilde.reshape((n*n,1)).T.dot(As_csc).A[0,:]-b_dense)
        
        ## solve dy = O^{-1} v
        try:
            dy = np.linalg.solve(O,v)
        except Exception:
            print('O near psd boundary! giving up.')
            break
            
        ## solve dS = A^T(dy) + (A^T(y) - S - C)
        dS = ep_dual + csc_matrix(As_csc.dot(dy).reshape((n,n)))
        ## solve dX = S^{-1}(dS X + SX - \mu I)
        dX = S_inv_op.solve_A(-(dS.dot(X) + ep_comp))
        dX = (dX + dX.T) / 2
        
        ## line search for step size
        alpha_p = line_search(X,dX)
        alpha_d = line_search(S,dS)
        if alpha_p < 0 or alpha_d < 0:
            psd_p,psd_d = 0,0
            try:
                psd_p,psd_d = np.min(cholesky(X).D()),np.min(cholesky(S).D())
            except Exception as e:
                pass
            print('X/S near psd boundary! giving up. '
                  'psd of primal={:.4e}, psd of dual={:.4e}.'.format(
                    psd_p,psd_d))
            break
            
        ## update the solution
        X = X + alpha_p * dX
        y = y + alpha_d * dy
        S = S + alpha_d * dS
        S_inv_op = cholesky(S)
        mu = np.sum((S.multiply(X)).data) / n / 2 ## tr(SX)
        if alpha_p + alpha_d > 1.8: ## good progress, so be more aggresive next step
            mu /= 2
            
        if iter_ % print_iter == 0:
            print('iter={}. elapsed time={:.2f}. mu={:.3f}, alphap={:.3f}, alphad={:.3f}.'.format(
                    iter_,time.time()-tt,mu,alpha_p,alpha_d))
            
    print('{}: total iter={}, elapsed time={:.2f}. objp={:.3e}, objd={:.3e}, '
          'errp={:.3e}, errd={:.3e}, errcs={:.3e}'.format(
            model_name,iter_,time.time()-total_tt,obj_primal,obj_dual,err_primal,err_dual,err_comp))

# %% [markdown]
# 接下来，我们通过SDPLIB中的测试案例来检验上述算法的正确性和计算效率。

# %%
for fname in fnames:
    if 'G' not in fname:
        solve(fname,print_iter=100)
# Out:
# arch0: model finish reading. n=335, m=174, nnz=3030.
# initialization scale: p=10.00, d=10.00.
# /Users/hanqiu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:56: CholmodTypeConversionWarning: converting matrix of class coo_matrix to CSC format
# /Users/hanqiu/Documents/GitHub/sdp_solve/util.py:109: CholmodTypeConversionWarning: converting matrix of class csr_matrix to CSC format
#   PdXPt = factor.apply_P(factor.apply_P(dX).T)
# /Users/hanqiu/Documents/GitHub/sdp_solve/util.py:110: CholmodTypeConversionWarning: converting matrix of class csr_matrix to CSC format
#   LiPdXPtLit = factor.solve_L(factor.solve_L(PdXPt,use_LDLt_decomposition=False).T,use_LDLt_decomposition=False)
# iter=100. objp=5.665e-01, objd=5.665e-01, errp=3.319e-04, errd=4.263e-14, errcs=1.168e-05
# iter=100. elapsed time=0.37. mu=0.000, alphap=0.000, alphad=0.019.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# arch0: total iter=141, elapsed time=51.33. objp=5.665e-01, objd=5.665e-01, errp=6.118e-04, errd=4.263e-14, errcs=1.150e-05
# arch2: model finish reading. n=335, m=174, nnz=3420.
# initialization scale: p=10.00, d=10.00.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# arch2: total iter=75, elapsed time=26.45. objp=6.715e-01, objd=6.715e-01, errp=2.678e-04, errd=2.842e-14, errcs=6.878e-06
# arch4: model finish reading. n=335, m=174, nnz=3420.
# initialization scale: p=10.00, d=10.00.
# iter=100. objp=9.726e-01, objd=9.726e-01, errp=2.557e-04, errd=2.842e-14, errcs=5.551e-06
# iter=100. elapsed time=0.34. mu=0.000, alphap=0.002, alphad=0.084.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# arch4: total iter=175, elapsed time=59.83. objp=9.726e-01, objd=9.726e-01, errp=3.681e-04, errd=1.137e-13, errcs=5.682e-06
# arch8: model finish reading. n=335, m=174, nnz=3420.
# initialization scale: p=10.00, d=10.00.
# iter=100. objp=2.137e+03, objd=1.205e+00, errp=1.560e+04, errd=2.344e-01, errcs=7.178e+01
# iter=100. elapsed time=0.34. mu=4.994, alphap=0.001, alphad=0.000.
# iter=200. objp=4.152e+00, objd=9.167e+00, errp=4.490e-09, errd=4.547e-13, errcs=4.136e-01
# iter=200. elapsed time=0.34. mu=0.007, alphap=0.104, alphad=1.000.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# arch8: total iter=248, elapsed time=82.87. objp=7.057e+00, objd=7.057e+00, errp=7.667e-04, errd=4.547e-13, errcs=6.003e-04
# control1: model finish reading. n=15, m=21, nnz=345.
# initialization scale: p=10.00, d=10.00.
# iter=100. objp=8.342e+01, objd=5.003e+01, errp=6.909e+00, errd=1.455e-11, errcs=8.536e+00
# iter=100. elapsed time=0.01. mu=0.108, alphap=0.014, alphad=0.057.
# iter=200. objp=1.803e+01, objd=1.780e+01, errp=8.764e-03, errd=2.910e-11, errcs=6.594e+00
# iter=200. elapsed time=0.01. mu=0.001, alphap=0.812, alphad=0.701.
# control1: total iter=207, elapsed time=1.48. objp=1.778e+01, objd=1.778e+01, errp=5.852e-08, errd=5.821e-11, errcs=2.506e-02
# control10: model finish reading. n=150, m=1326, nnz=313950.
# initialization scale: p=10.00, d=10.00.
# iter=100. objp=3.853e+01, objd=3.853e+01, errp=2.313e-06, errd=2.328e-09, errcs=7.272e-03
# iter=100. elapsed time=5.07. mu=0.000, alphap=0.006, alphad=0.011.
# iter=200. objp=3.853e+01, objd=3.853e+01, errp=1.753e-06, errd=1.863e-09, errcs=1.699e-02
# iter=200. elapsed time=5.11. mu=0.000, alphap=0.013, alphad=0.036.
# control10: total iter=247, elapsed time=1200.43. objp=3.853e+01, objd=3.853e+01, errp=2.059e-06, errd=5.588e-09, errcs=2.095e-02
# control11: model finish reading. n=165, m=1596, nnz=417670.
# initialization scale: p=10.00, d=10.00.
# iter=100. objp=3.196e+01, objd=3.196e+01, errp=4.124e-06, errd=2.328e-09, errcs=1.222e-02
# iter=100. elapsed time=7.69. mu=0.000, alphap=0.033, alphad=0.142.
# control11: total iter=164, elapsed time=1204.45. objp=3.196e+01, objd=3.196e+01, errp=3.151e-06, errd=1.397e-09, errcs=1.773e-02
# control2: model finish reading. n=30, m=66, nnz=2590.
# initialization scale: p=10.00, d=10.00.
# control2: total iter=97, elapsed time=1.15. objp=8.300e+00, objd=8.300e+00, errp=1.391e-07, errd=2.910e-11, errcs=2.757e-04
# control3: model finish reading. n=45, m=136, nnz=8610.
# initialization scale: p=10.00, d=10.00.
# iter=100. objp=1.363e+01, objd=1.363e+01, errp=1.929e-09, errd=2.328e-10, errcs=3.650e-02
# iter=100. elapsed time=0.02. mu=0.000, alphap=1.000, alphad=1.000.
# control3: total iter=104, elapsed time=2.88. objp=1.363e+01, objd=1.363e+01, errp=4.856e-07, errd=1.746e-10, errcs=1.290e-03
# control4: model finish reading. n=60, m=231, nnz=20280.
# initialization scale: p=10.00, d=10.00.
# iter=100. objp=2.575e+01, objd=2.241e+01, errp=1.432e-01, errd=1.746e-10, errcs=1.134e+01
# iter=100. elapsed time=0.07. mu=0.042, alphap=0.533, alphad=0.491.
# X/S near psd boundary! giving up. psd of primal=-4.9569e-13, psd of dual=3.3133e-09.
# control4: total iter=167, elapsed time=12.40. objp=1.979e+01, objd=1.979e+01, errp=4.858e-05, errd=1.746e-10, errcs=9.849e-03
# control5: model finish reading. n=75, m=351, nnz=39475.
# initialization scale: p=10.00, d=10.00.
# iter=100. objp=1.688e+01, objd=1.688e+01, errp=2.225e-06, errd=3.492e-10, errcs=2.204e-03
# iter=100. elapsed time=0.19. mu=0.000, alphap=0.072, alphad=0.337.
# iter=200. objp=1.688e+01, objd=1.688e+01, errp=4.847e-06, errd=3.492e-10, errcs=7.598e-03
# iter=200. elapsed time=0.21. mu=0.000, alphap=0.001, alphad=0.002.
# iter=300. objp=1.688e+01, objd=1.688e+01, errp=9.184e-06, errd=2.910e-10, errcs=1.685e-02
# iter=300. elapsed time=0.24. mu=0.000, alphap=0.002, alphad=0.023.
# iter=400. objp=1.688e+01, objd=1.688e+01, errp=2.638e-05, errd=3.492e-10, errcs=7.294e-03
# iter=400. elapsed time=0.20. mu=0.000, alphap=0.014, alphad=0.247.
# iter=500. objp=1.688e+01, objd=1.688e+01, errp=3.657e-05, errd=5.821e-10, errcs=1.061e-02
# iter=500. elapsed time=0.20. mu=0.000, alphap=0.008, alphad=0.117.
# iter=600. objp=1.688e+01, objd=1.688e+01, errp=1.900e-05, errd=3.492e-10, errcs=9.238e-03
# iter=600. elapsed time=0.20. mu=0.000, alphap=0.002, alphad=0.118.
# iter=700. objp=1.688e+01, objd=1.688e+01, errp=1.821e-05, errd=3.492e-10, errcs=8.684e-03
# iter=700. elapsed time=0.19. mu=0.000, alphap=0.003, alphad=0.051.
# iter=800. objp=1.688e+01, objd=1.688e+01, errp=3.503e-05, errd=3.492e-10, errcs=6.894e-03
# iter=800. elapsed time=0.19. mu=0.000, alphap=0.000, alphad=0.024.
# iter=900. objp=1.688e+01, objd=1.688e+01, errp=4.636e-05, errd=3.492e-10, errcs=6.567e-03
# iter=900. elapsed time=0.19. mu=0.000, alphap=0.001, alphad=0.006.
# X/S near psd boundary! giving up. psd of primal=-4.1062e-12, psd of dual=5.8998e-09.
# control5: total iter=980, elapsed time=198.25. objp=1.688e+01, objd=1.688e+01, errp=4.693e-05, errd=2.328e-10, errcs=6.645e-03
# control6: model finish reading. n=90, m=496, nnz=68070.
# initialization scale: p=10.00, d=10.00.
# iter=100. objp=1.848e+02, objd=1.239e+02, errp=5.521e+00, errd=5.821e-11, errcs=9.140e+00
# iter=100. elapsed time=0.43. mu=0.196, alphap=0.110, alphad=0.187.
# iter=200. objp=3.730e+01, objd=3.730e+01, errp=1.298e-05, errd=9.313e-10, errcs=1.746e-02
# iter=200. elapsed time=0.43. mu=0.000, alphap=0.039, alphad=0.129.
# iter=300. objp=3.730e+01, objd=3.730e+01, errp=1.172e-05, errd=6.985e-10, errcs=2.563e-02
# iter=300. elapsed time=0.42. mu=0.000, alphap=0.028, alphad=0.116.
# iter=400. objp=3.730e+01, objd=3.730e+01, errp=2.073e-05, errd=1.863e-09, errcs=7.050e-02
# iter=400. elapsed time=0.44. mu=0.000, alphap=0.000, alphad=0.000.
# X/S near psd boundary! giving up. psd of primal=-1.9455e-13, psd of dual=8.5101e-09.
# control6: total iter=427, elapsed time=178.36. objp=3.730e+01, objd=3.730e+01, errp=4.186e-05, errd=1.397e-09, errcs=4.801e-02
# control7: model finish reading. n=105, m=666, nnz=107940.
# initialization scale: p=10.00, d=10.00.
# iter=100. objp=2.063e+01, objd=2.063e+01, errp=5.133e-06, errd=6.985e-10, errcs=8.420e-03
# iter=100. elapsed time=0.91. mu=0.000, alphap=0.006, alphad=0.026.
# iter=200. objp=2.063e+01, objd=2.063e+01, errp=5.401e-06, errd=9.313e-10, errcs=2.889e-02
# iter=200. elapsed time=0.90. mu=0.000, alphap=0.001, alphad=0.004.
# iter=300. objp=2.063e+01, objd=2.063e+01, errp=7.665e-06, errd=1.164e-09, errcs=1.594e-02
# iter=300. elapsed time=0.88. mu=0.000, alphap=0.000, alphad=0.000.
# iter=400. objp=2.063e+01, objd=2.063e+01, errp=1.275e-05, errd=1.397e-09, errcs=1.951e-02
# iter=400. elapsed time=0.88. mu=0.000, alphap=0.000, alphad=0.004.
# iter=500. objp=2.063e+01, objd=2.063e+01, errp=1.117e-05, errd=9.313e-10, errcs=1.977e-02
# iter=500. elapsed time=0.93. mu=0.000, alphap=0.008, alphad=0.041.
# iter=600. objp=2.063e+01, objd=2.063e+01, errp=1.587e-05, errd=1.630e-09, errcs=1.588e-02
# iter=600. elapsed time=0.88. mu=0.000, alphap=0.001, alphad=0.009.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# control7: total iter=640, elapsed time=566.01. objp=2.063e+01, objd=2.063e+01, errp=2.972e-05, errd=1.397e-09, errcs=1.943e-02
# control8: model finish reading. n=120, m=861, nnz=160960.
# initialization scale: p=10.00, d=10.00.
# control8: total iter=94, elapsed time=146.79. objp=2.029e+01, objd=2.029e+01, errp=8.843e-07, errd=9.313e-10, errcs=2.314e-03
# control9: model finish reading. n=135, m=1081, nnz=229005.
# initialization scale: p=10.00, d=10.00.
# control9: total iter=84, elapsed time=223.64. objp=1.468e+01, objd=1.468e+01, errp=5.516e-07, errd=9.313e-10, errcs=1.575e-03
# gpp100: model finish reading. n=100, m=101, nnz=5150.
# initialization scale: p=10.00, d=15.31.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# gpp100: total iter=73, elapsed time=6.90. objp=-4.506e+01, objd=-4.494e+01, errp=7.086e-05, errd=2.980e-08, errcs=2.255e+03
# gpp124-1: model finish reading. n=124, m=125, nnz=7874.
# initialization scale: p=10.00, d=10.00.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# gpp124-1: total iter=25, elapsed time=4.13. objp=-7.441e+00, objd=-7.341e+00, errp=2.244e-05, errd=1.863e-09, errcs=1.664e+02
# gpp124-2: model finish reading. n=124, m=125, nnz=7874.
# initialization scale: p=10.00, d=15.04.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# gpp124-2: total iter=54, elapsed time=8.99. objp=-4.694e+01, objd=-4.686e+01, errp=6.680e-05, errd=7.451e-09, errcs=7.832e+02
# gpp124-3: model finish reading. n=124, m=125, nnz=7874.
# initialization scale: p=10.00, d=27.53.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# gpp124-3: total iter=30, elapsed time=4.92. objp=-1.532e+02, objd=-1.530e+02, errp=5.607e-05, errd=7.451e-09, errcs=5.682e+02
# gpp124-4: model finish reading. n=124, m=125, nnz=7874.
# initialization scale: p=10.00, d=53.44.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# gpp124-4: total iter=79, elapsed time=13.05. objp=-4.196e+02, objd=-4.190e+02, errp=6.043e-05, errd=5.960e-08, errcs=7.596e+03
# gpp250-1: model finish reading. n=250, m=251, nnz=31625.
# initialization scale: p=10.00, d=10.00.
# X/S near psd boundary! giving up. psd of primal=3.1434e-14, psd of dual=3.5716e-04.
# gpp250-1: total iter=25, elapsed time=41.98. objp=-1.562e+01, objd=-1.544e+01, errp=7.859e-05, errd=4.657e-10, errcs=6.284e+01
# gpp250-2: model finish reading. n=250, m=251, nnz=31625.
# initialization scale: p=10.00, d=14.34.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# gpp250-2: total iter=61, elapsed time=102.55. objp=-8.221e+01, objd=-8.186e+01, errp=6.945e-05, errd=7.451e-09, errcs=8.082e+02
# gpp250-3: model finish reading. n=250, m=251, nnz=31625.
# initialization scale: p=10.00, d=27.90.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# gpp250-3: total iter=37, elapsed time=61.77. objp=-3.040e+02, objd=-3.035e+02, errp=2.976e-05, errd=3.725e-09, errcs=4.979e+02
# gpp250-4: model finish reading. n=250, m=251, nnz=31625.
# initialization scale: p=10.00, d=50.70.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# gpp250-4: total iter=74, elapsed time=124.60. objp=-7.488e+02, objd=-7.473e+02, errp=6.084e-05, errd=2.980e-08, errcs=4.418e+03
# gpp500-1: model finish reading. n=500, m=501, nnz=125750.
# initialization scale: p=10.00, d=10.00.
# gpp500-1: total iter=61, elapsed time=1203.15. objp=-2.562e+01, objd=-2.532e+01, errp=1.428e-04, errd=1.863e-09, errcs=3.102e+02
# gpp500-2: model finish reading. n=500, m=501, nnz=125750.
# initialization scale: p=10.00, d=14.55.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# gpp500-2: total iter=37, elapsed time=728.00. objp=-1.562e+02, objd=-1.561e+02, errp=9.394e-05, errd=4.657e-10, errcs=8.227e+01
# gpp500-3: model finish reading. n=500, m=501, nnz=125750.
# initialization scale: p=10.00, d=25.85.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# gpp500-3: total iter=43, elapsed time=843.21. objp=-5.139e+02, objd=-5.130e+02, errp=2.676e-05, errd=3.725e-09, errcs=5.709e+02
# gpp500-4: model finish reading. n=500, m=501, nnz=125750.
# initialization scale: p=10.00, d=53.51.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# gpp500-4: total iter=40, elapsed time=783.61. objp=-1.570e+03, objd=-1.567e+03, errp=1.365e-05, errd=7.451e-09, errcs=1.079e+03
# hinf1: model finish reading. n=14, m=13, nnz=92.
# initialization scale: p=10.00, d=10.00.
# O near psd boundary! giving up.
# hinf1: total iter=25, elapsed time=0.14. objp=2.033e+00, objd=2.033e+00, errp=2.588e-07, errd=5.821e-11, errcs=6.212e-03
# hinf10: model finish reading. n=18, m=21, nnz=190.
# initialization scale: p=10.00, d=96.58.
# X/S near psd boundary! giving up. psd of primal=1.0000e-16, psd of dual=4.1977e-07.
# hinf10: total iter=91, elapsed time=0.66. objp=1.088e+02, objd=1.088e+02, errp=1.724e-04, errd=1.514e-02, errcs=3.272e+01
# hinf11: model finish reading. n=22, m=31, nnz=417.
# initialization scale: p=10.00, d=112.79.
# X/S near psd boundary! giving up. psd of primal=1.0000e-16, psd of dual=1.4266e-07.
# hinf11: total iter=71, elapsed time=0.57. objp=6.592e+01, objd=6.589e+01, errp=5.028e-05, errd=5.379e-04, errcs=4.921e+00
# hinf12: model finish reading. n=24, m=43, nnz=579.
# initialization scale: p=10.00, d=44.25.
# iter=100. objp=1.995e-03, objd=2.043e-03, errp=2.627e-09, errd=4.783e-06, errcs=9.123e-01
# iter=100. elapsed time=0.01. mu=0.000, alphap=0.323, alphad=0.240.
# X/S near psd boundary! giving up. psd of primal=1.0000e-16, psd of dual=1.8929e-05.
# hinf12: total iter=115, elapsed time=0.93. objp=5.386e-05, objd=4.493e-05, errp=1.550e-10, errd=9.766e-04, errcs=1.152e+01
# hinf13: model finish reading. n=30, m=57, nnz=1444.
# initialization scale: p=10.00, d=10.00.
# iter=100. objp=4.435e+01, objd=4.435e+01, errp=1.506e-02, errd=1.118e-08, errcs=4.994e+03
# iter=100. elapsed time=0.01. mu=0.000, alphap=0.005, alphad=0.075.
# iter=200. objp=4.435e+01, objd=4.435e+01, errp=5.182e-03, errd=1.669e-06, errcs=9.741e+04
# iter=200. elapsed time=0.01. mu=0.000, alphap=0.000, alphad=0.000.
# iter=300. objp=4.435e+01, objd=4.435e+01, errp=5.150e-03, errd=2.742e-06, errcs=1.027e+05
# iter=300. elapsed time=0.01. mu=0.000, alphap=0.000, alphad=0.000.
# X/S near psd boundary! giving up. psd of primal=1.0000e-16, psd of dual=2.5767e-06.
# hinf13: total iter=315, elapsed time=3.30. objp=4.435e+01, objd=4.435e+01, errp=5.149e-03, errd=2.861e-06, errcs=8.987e+04
# hinf14: model finish reading. n=34, m=73, nnz=2394.
# initialization scale: p=10.00, d=10.00.
# iter=100. objp=1.299e+01, objd=1.299e+01, errp=1.206e-05, errd=3.725e-09, errcs=1.403e+01
# iter=100. elapsed time=0.01. mu=0.000, alphap=0.005, alphad=0.006.
# iter=200. objp=1.299e+01, objd=1.299e+01, errp=1.033e-05, errd=3.228e-08, errcs=8.241e+00
# iter=200. elapsed time=0.01. mu=0.000, alphap=0.001, alphad=0.004.
# iter=300. objp=1.299e+01, objd=1.299e+01, errp=3.074e-05, errd=1.176e-08, errcs=8.022e+00
# iter=300. elapsed time=0.01. mu=0.000, alphap=0.004, alphad=0.005.
# iter=400. objp=1.299e+01, objd=1.299e+01, errp=2.854e-05, errd=1.839e-08, errcs=5.337e+00
# iter=400. elapsed time=0.01. mu=0.000, alphap=0.006, alphad=0.004.
# iter=500. objp=1.299e+01, objd=1.299e+01, errp=2.222e-05, errd=6.240e-08, errcs=1.050e+01
# iter=500. elapsed time=0.01. mu=0.000, alphap=0.000, alphad=0.000.
# iter=600. objp=1.299e+01, objd=1.299e+01, errp=2.086e-05, errd=2.682e-07, errcs=1.525e+01
# iter=600. elapsed time=0.01. mu=0.000, alphap=0.000, alphad=0.002.
# iter=700. objp=1.299e+01, objd=1.299e+01, errp=2.142e-05, errd=3.092e-07, errcs=1.957e+01
# iter=700. elapsed time=0.01. mu=0.000, alphap=0.000, alphad=0.000.
# X/S near psd boundary! giving up. psd of primal=1.0000e-16, psd of dual=4.2595e-06.
# hinf14: total iter=783, elapsed time=8.06. objp=1.299e+01, objd=1.299e+01, errp=1.911e-05, errd=3.651e-07, errcs=2.587e+01
# hinf15: model finish reading. n=37, m=91, nnz=3394.
# initialization scale: p=10.00, d=10.00.
# iter=100. objp=2.398e+01, objd=2.398e+01, errp=1.788e-02, errd=5.821e-10, errcs=4.813e+02
# iter=100. elapsed time=0.01. mu=0.001, alphap=0.047, alphad=0.052.
# iter=200. objp=2.397e+01, objd=2.396e+01, errp=3.842e-02, errd=9.537e-06, errcs=9.378e+04
# iter=200. elapsed time=0.01. mu=0.006, alphap=0.000, alphad=0.000.
# iter=300. objp=2.397e+01, objd=2.396e+01, errp=3.838e-02, errd=1.049e-05, errcs=9.170e+04
# iter=300. elapsed time=0.01. mu=0.005, alphap=0.000, alphad=0.000.
# iter=400. objp=2.397e+01, objd=2.396e+01, errp=3.834e-02, errd=1.097e-05, errcs=6.189e+04
# iter=400. elapsed time=0.02. mu=0.005, alphap=0.000, alphad=0.000.
# iter=500. objp=2.397e+01, objd=2.396e+01, errp=3.829e-02, errd=1.049e-05, errcs=5.149e+04
# iter=500. elapsed time=0.01. mu=0.005, alphap=0.000, alphad=0.000.
# iter=600. objp=2.397e+01, objd=2.396e+01, errp=3.826e-02, errd=1.001e-05, errcs=4.168e+04
# iter=600. elapsed time=0.01. mu=0.005, alphap=0.000, alphad=0.000.
# iter=700. objp=2.397e+01, objd=2.396e+01, errp=3.823e-02, errd=1.240e-05, errcs=1.840e+04
# iter=700. elapsed time=0.01. mu=0.004, alphap=0.000, alphad=0.000.
# iter=800. objp=2.397e+01, objd=2.396e+01, errp=3.820e-02, errd=1.192e-05, errcs=1.235e+04
# iter=800. elapsed time=0.01. mu=0.004, alphap=0.000, alphad=0.000.
# iter=900. objp=2.397e+01, objd=2.396e+01, errp=3.817e-02, errd=9.537e-06, errcs=1.211e+04
# iter=900. elapsed time=0.01. mu=0.004, alphap=0.000, alphad=0.000.
# iter=1000. objp=2.397e+01, objd=2.396e+01, errp=3.814e-02, errd=1.335e-05, errcs=1.304e+04
# X/S near psd boundary! giving up. psd of primal=1.0000e-16, psd of dual=3.6055e-07.
# hinf15: total iter=1000, elapsed time=12.75. objp=2.397e+01, objd=2.396e+01, errp=3.814e-02, errd=1.335e-05, errcs=1.304e+04
# hinf2: model finish reading. n=16, m=13, nnz=118.
# initialization scale: p=10.00, d=10.00.
# X/S near psd boundary! giving up. psd of primal=-1.4948e-13, psd of dual=4.7229e-09.
# hinf2: total iter=97, elapsed time=0.66. objp=1.097e+01, objd=1.097e+01, errp=5.893e-03, errd=1.819e-12, errcs=7.120e-01
# hinf3: model finish reading. n=16, m=13, nnz=118.
# initialization scale: p=10.00, d=14.15.
# iter=100. objp=5.695e+01, objd=5.695e+01, errp=4.901e-03, errd=9.095e-13, errcs=4.584e-01
# iter=100. elapsed time=0.01. mu=0.000, alphap=0.002, alphad=0.157.
# O near psd boundary! giving up.
# hinf3: total iter=158, elapsed time=0.93. objp=5.695e+01, objd=5.695e+01, errp=4.242e-03, errd=1.819e-12, errcs=5.040e-01
# hinf4: model finish reading. n=16, m=13, nnz=118.
# initialization scale: p=10.00, d=46.04.
# O near psd boundary! giving up.
# hinf4: total iter=47, elapsed time=0.27. objp=2.748e+02, objd=2.748e+02, errp=3.346e-04, errd=5.821e-09, errcs=8.847e+00
# hinf5: model finish reading. n=16, m=13, nnz=118.
# initialization scale: p=10.00, d=63.98.
# X/S near psd boundary! giving up. psd of primal=-1.0782e-08, psd of dual=8.8180e-10.
# hinf5: total iter=42, elapsed time=0.28. objp=3.625e+02, objd=3.624e+02, errp=1.044e-01, errd=1.819e-11, errcs=9.957e+00
# hinf6: model finish reading. n=16, m=13, nnz=118.
# initialization scale: p=10.00, d=29.46.
# O near psd boundary! giving up.
# hinf6: total iter=82, elapsed time=0.51. objp=4.489e+02, objd=4.489e+02, errp=2.076e-03, errd=1.019e-10, errcs=7.483e+01
# hinf7: model finish reading. n=16, m=13, nnz=118.
# initialization scale: p=10.00, d=81.57.
# iter=100. objp=3.908e+02, objd=3.908e+02, errp=2.862e+00, errd=4.352e-11, errcs=2.000e+01
# iter=100. elapsed time=0.01. mu=0.000, alphap=0.000, alphad=1.000.
# X/S near psd boundary! giving up. psd of primal=-1.6535e-13, psd of dual=9.2018e-09.
# hinf7: total iter=180, elapsed time=1.06. objp=3.908e+02, objd=3.908e+02, errp=2.573e+00, errd=8.548e-12, errcs=2.376e+01
# hinf8: model finish reading. n=16, m=13, nnz=118.
# initialization scale: p=10.00, d=47.14.
# O near psd boundary! giving up.
# hinf8: total iter=81, elapsed time=0.45. objp=1.162e+02, objd=1.161e+02, errp=3.342e-03, errd=4.366e-11, errcs=3.681e+00
# hinf9: model finish reading. n=16, m=13, nnz=118.
# initialization scale: p=10.00, d=71.36.
# iter=100. objp=2.363e+02, objd=2.362e+02, errp=1.668e+00, errd=5.418e-13, errcs=7.314e-01
# iter=100. elapsed time=0.01. mu=0.000, alphap=0.000, alphad=1.000.
# X/S near psd boundary! giving up. psd of primal=-3.0163e-12, psd of dual=1.0784e-12.
# hinf9: total iter=184, elapsed time=1.06. objp=2.363e+02, objd=2.362e+02, errp=3.238e+00, errd=2.274e-13, errcs=8.387e-01
# infd1: model finish reading. n=30, m=10, nnz=4650.
# initialization scale: p=10.00, d=2076.44.
# iter=100. objp=4.040e+00, objd=-1.458e+275, errp=1.240e+01, errd=2.460e+260, errcs=9.966e+270
# iter=100. elapsed time=0.01. mu=.000, alphap=0.000, alphad=1.000.
# X/S near psd boundary! giving up. psd of primal=1.1560e-10, psd of dual=1.6695e+296.
# infd1: total iter=106, elapsed time=0.93. objp=4.040e+00, objd=-1.794e+304, errp=1.240e+01, errd=1.949e+289, errcs=1.143e+300
# infd2: model finish reading. n=30, m=10, nnz=4650.
# initialization scale: p=10.00, d=399.31.
# iter=100. objp=-5.309e+00, objd=-2.549e+245, errp=5.363e+00, errd=2.911e+230, errcs=3.533e+241
# iter=100. elapsed time=0.01. mu=4199732738673145946072032449027753825502991374958306113174253264843357709361714281833613891908210636597659347863298741573236538476222503725281785457688215414479474782526254414249309298911490157209858135598775120260320143465807310540953207439360.000, alphap=0.000, alphad=1.000.
# X/S near psd boundary! giving up. psd of primal=9.0187e-11, psd of dual=5.3028e+300.
# infd2: total iter=114, elapsed time=0.98. objp=-5.309e+00, objd=-6.306e+307, errp=5.363e+00, errd=3.992e+292, errcs=7.573e+303
# infp1: model finish reading. n=30, m=10, nnz=4650.
# initialization scale: p=17.15, d=22.68.
# X/S near psd boundary! giving up. psd of primal=5.4608e-04, psd of dual=-4.4379e-15.
# infp1: total iter=48, elapsed time=0.45. objp=7.277e+04, objd=7.547e+00, errp=2.667e-11, errd=5.607e+00, errcs=2.135e+02
# infp2: model finish reading. n=30, m=10, nnz=4650.
# initialization scale: p=12.93, d=22.60.
# iter=100. objp=7.703e+04, objd=7.364e+00, errp=3.669e-11, errd=5.959e+00, errcs=2.614e+02
# iter=100. elapsed time=0.01. mu=60.608, alphap=0.000, alphad=0.000.
# X/S near psd boundary! giving up. psd of primal=7.7144e-04, psd of dual=-8.4932e-16.
# infp2: total iter=162, elapsed time=1.39. objp=1.115e+05, objd=7.789e+00, errp=6.417e-11, errd=5.957e+00, errcs=3.715e+02
# mcp100: model finish reading. n=100, m=100, nnz=100.
# initialization scale: p=10.00, d=15.64.
# mcp100: total iter=18, elapsed time=0.69. objp=2.262e+02, objd=2.262e+02, errp=1.627e-10, errd=4.441e-16, errcs=2.861e-05
# mcp124-1: model finish reading. n=124, m=124, nnz=124.
# initialization scale: p=10.00, d=10.00.
# mcp124-1: total iter=20, elapsed time=1.13. objp=1.420e+02, objd=1.420e+02, errp=5.285e-10, errd=2.220e-16, errcs=4.329e-06
# mcp124-2: model finish reading. n=124, m=124, nnz=124.
# initialization scale: p=10.00, d=15.04.
# mcp124-2: total iter=19, elapsed time=1.26. objp=2.699e+02, objd=2.699e+02, errp=7.083e-10, errd=4.441e-16, errcs=9.578e-06
# mcp124-3: model finish reading. n=124, m=124, nnz=124.
# initialization scale: p=10.00, d=27.53.
# mcp124-3: total iter=18, elapsed time=1.29. objp=4.677e+02, objd=4.678e+02, errp=7.533e-10, errd=8.882e-16, errcs=1.663e-05
# mcp124-4: model finish reading. n=124, m=124, nnz=124.
# initialization scale: p=10.00, d=53.44.
# mcp124-4: total iter=18, elapsed time=2.41. objp=8.644e+02, objd=8.644e+02, errp=2.868e-10, errd=1.776e-15, errcs=1.908e-05
# mcp250-1: model finish reading. n=250, m=250, nnz=250.
# initialization scale: p=10.00, d=10.00.
# mcp250-1: total iter=22, elapsed time=9.13. objp=3.173e+02, objd=3.173e+02, errp=2.253e-10, errd=2.220e-16, errcs=1.274e-05
# mcp250-2: model finish reading. n=250, m=250, nnz=250.
# initialization scale: p=10.00, d=14.34.
# mcp250-2: total iter=19, elapsed time=10.54. objp=5.319e+02, objd=5.319e+02, errp=2.386e-10, errd=8.882e-16, errcs=1.953e-05
# mcp250-3: model finish reading. n=250, m=250, nnz=250.
# initialization scale: p=10.00, d=27.90.
# mcp250-3: total iter=19, elapsed time=21.53. objp=9.812e+02, objd=9.812e+02, errp=3.418e-10, errd=8.882e-16, errcs=3.299e-05
# mcp250-4: model finish reading. n=250, m=250, nnz=250.
# initialization scale: p=10.00, d=50.70.
# mcp250-4: total iter=19, elapsed time=24.54. objp=1.682e+03, objd=1.682e+03, errp=1.540e-10, errd=1.776e-15, errcs=6.642e-05
# mcp500-1: model finish reading. n=500, m=500, nnz=500.
# initialization scale: p=10.00, d=10.00.
# mcp500-1: total iter=24, elapsed time=88.94. objp=5.981e+02, objd=5.981e+02, errp=7.715e-10, errd=4.441e-16, errcs=1.507e-05
# mcp500-2: model finish reading. n=500, m=500, nnz=500.
# initialization scale: p=10.00, d=14.55.
# mcp500-2: total iter=23, elapsed time=212.50. objp=1.070e+03, objd=1.070e+03, errp=8.785e-10, errd=4.441e-16, errcs=6.837e-06
# mcp500-3: model finish reading. n=500, m=500, nnz=500.
# initialization scale: p=10.00, d=25.85.
# mcp500-3: total iter=21, elapsed time=261.91. objp=1.848e+03, objd=1.848e+03, errp=6.502e-10, errd=8.882e-16, errcs=9.846e-06
# mcp500-4: model finish reading. n=500, m=500, nnz=500.
# initialization scale: p=10.00, d=53.51.
# mcp500-4: total iter=19, elapsed time=318.95. objp=3.567e+03, objd=3.567e+03, errp=4.056e-10, errd=1.776e-15, errcs=5.298e-05
# qap10: model finish reading. n=101, m=1021, nnz=13101.
# initialization scale: p=10.00, d=2400.01.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# qap10: total iter=61, elapsed time=48.91. objp=-1.093e+03, objd=-1.093e+03, errp=1.873e-04, errd=6.985e-10, errcs=1.476e+00
# qap5: model finish reading. n=26, m=136, nnz=1026.
# initialization scale: p=10.00, d=590.54.
# X/S near psd boundary! giving up. psd of primal=-6.6281e-16, psd of dual=6.9400e-08.
# qap5: total iter=34, elapsed time=0.43. objp=-4.360e+02, objd=-4.360e+02, errp=1.957e-04, errd=1.397e-09, errcs=1.051e+00
# qap6: model finish reading. n=37, m=229, nnz=1981.
# initialization scale: p=10.00, d=883.99.
# X/S near psd boundary! giving up. psd of primal=-1.0357e-16, psd of dual=1.7396e-07.
# qap6: total iter=92, elapsed time=2.18. objp=-3.814e+02, objd=-3.814e+02, errp=7.356e-04, errd=6.985e-10, errcs=1.366e+00
# qap7: model finish reading. n=50, m=358, nnz=3480.
# initialization scale: p=10.00, d=960.11.
# X/S near psd boundary! giving up. psd of primal=-2.1621e-16, psd of dual=5.3571e-08.
# qap7: total iter=70, elapsed time=4.03. objp=-4.248e+02, objd=-4.248e+02, errp=3.137e-05, errd=6.985e-10, errcs=1.464e+00
# qap8: model finish reading. n=65, m=529, nnz=5697.
# initialization scale: p=10.00, d=1539.01.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# qap8: total iter=71, elapsed time=12.14. objp=-7.570e+02, objd=-7.570e+02, errp=5.229e-04, errd=3.725e-09, errcs=4.780e+00
# qap9: model finish reading. n=82, m=748, nnz=8830.
# initialization scale: p=10.00, d=2407.92.
# iter=100. objp=-1.410e+03, objd=-1.410e+03, errp=6.409e-04, errd=9.313e-10, errcs=2.852e+00
# iter=100. elapsed time=0.39. mu=0.000, alphap=0.000, alphad=0.017.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# qap9: total iter=115, elapsed time=43.62. objp=-1.410e+03, objd=-1.410e+03, errp=9.544e-04, errd=6.985e-10, errcs=1.947e+00
# ss30: model finish reading. n=426, m=132, nnz=6642.
# initialization scale: p=10.00, d=10.00.
# iter=100. objp=2.024e+01, objd=2.024e+01, errp=1.406e-04, errd=5.684e-14, errcs=1.122e-03
# iter=100. elapsed time=0.85. mu=0.000, alphap=0.016, alphad=1.000.
# X/S near psd boundary! giving up. psd of primal=0.0000e+00, psd of dual=0.0000e+00.
# ss30: total iter=187, elapsed time=163.33. objp=2.024e+01, objd=2.024e+01, errp=1.932e-04, errd=8.527e-14, errcs=9.785e-04
# theta1: model finish reading. n=50, m=104, nnz=153.
# initialization scale: p=10.00, d=50.00.
# theta1: total iter=21, elapsed time=0.38. objp=2.300e+01, objd=2.300e+01, errp=2.298e-09, errd=1.776e-15, errcs=7.898e-06
# theta2: model finish reading. n=100, m=498, nnz=597.
# initialization scale: p=10.00, d=100.00.
# theta2: total iter=20, elapsed time=6.58. objp=3.288e+01, objd=3.288e+01, errp=3.885e-10, errd=3.553e-15, errcs=5.554e-06
# theta3: model finish reading. n=150, m=1106, nnz=1255.
# initialization scale: p=10.00, d=122.47.
# theta3: total iter=20, elapsed time=36.19. objp=4.217e+01, objd=4.217e+01, errp=3.303e-10, errd=1.776e-15, errcs=3.137e-06
# theta4: model finish reading. n=200, m=1949, nnz=2148.
# initialization scale: p=10.00, d=141.42.
# theta4: total iter=21, elapsed time=146.08. objp=5.032e+01, objd=5.032e+01, errp=1.590e-10, errd=1.776e-15, errcs=2.292e-06
# theta5: model finish reading. n=250, m=3028, nnz=3277.
# initialization scale: p=10.00, d=158.11.
# theta5: total iter=23, elapsed time=445.38. objp=5.723e+01, objd=5.723e+01, errp=4.416e-11, errd=1.776e-15, errcs=1.330e-06
# theta6: model finish reading. n=300, m=4375, nnz=4674.
# initialization scale: p=10.00, d=173.21.
# theta6: total iter=20, elapsed time=1265.07. objp=6.347e+01, objd=6.348e+01, errp=6.315e-13, errd=1.776e-15, errcs=4.164e-05
# truss1: model finish reading. n=13, m=6, nnz=25.
# initialization scale: p=10.00, d=10.00.
# truss1: total iter=16, elapsed time=0.15. objp=-9.000e+00, objd=-9.000e+00, errp=1.549e-09, errd=8.882e-16, errcs=4.381e-05
# truss2: model finish reading. n=133, m=58, nnz=567.
# initialization scale: p=10.00, d=10.00.
# truss2: total iter=20, elapsed time=0.37. objp=-1.234e+02, objd=-1.234e+02, errp=1.197e-07, errd=7.105e-15, errcs=7.191e-04
# truss3: model finish reading. n=31, m=27, nnz=118.
# initialization scale: p=10.00, d=10.00.
# truss3: total iter=21, elapsed time=0.15. objp=-9.110e+00, objd=-9.110e+00, errp=1.342e-08, errd=4.441e-16, errcs=2.301e-04
# truss4: model finish reading. n=19, m=12, nnz=50.
# initialization scale: p=10.00, d=10.00.
# truss4: total iter=18, elapsed time=0.09. objp=-9.010e+00, objd=-9.010e+00, errp=1.535e-09, errd=1.332e-15, errcs=1.343e-05
# truss5: model finish reading. n=331, m=208, nnz=2823.
# initialization scale: p=10.00, d=10.00.
# truss5: total iter=24, elapsed time=3.10. objp=-1.326e+02, objd=-1.326e+02, errp=4.375e-07, errd=3.997e-15, errcs=3.770e-04
# truss6: model finish reading. n=451, m=172, nnz=1726.
# initialization scale: p=10.00, d=10.00.
# truss6: total iter=45, elapsed time=6.65. objp=-9.010e+02, objd=-9.010e+02, errp=4.414e-07, errd=1.172e-13, errcs=2.823e-03
# truss7: model finish reading. n=301, m=86, nnz=863.
# initialization scale: p=10.00, d=10.00.
# truss7: total iter=52, elapsed time=2.24. objp=-9.000e+02, objd=-9.000e+02, errp=3.412e-07, errd=1.243e-13, errcs=1.393e-03
# truss8: model finish reading. n=628, m=496, nnz=8286.
# initialization scale: p=10.00, d=10.00.
# X/S near psd boundary! giving up. psd of primal=8.0598e-17, psd of dual=4.3297e-13.
# truss8: total iter=52, elapsed time=62.87. objp=-1.331e+02, objd=-1.331e+02, errp=9.775e-04, errd=9.104e-15, errcs=1.251e-03

# %% [markdown]
# 可以看出，上面的算法实现基本可以得到正确结果，但计算效率比CSDP慢10~100倍，这主要包含两方面原因：
# 1. 迭代效率：在不同测试问题上，上述实现的迭代数通常比CSDP高好几倍。这是由于上述实现在步长选取、迭代步更新（是否引入预估-校正步骤）等方面都使用了最基础的技术，相比CSDP经过一定优化的实现有明显差距；
# 2. 底层计算效率：虽然最终执行的都是经过优化的C代码，但上述实现是基于Python的，需要增加一定的语言转换开销。另外，在利用问题矩阵$A$和$C$的稀疏性和分块特征上，通用的线性代数函数也没有CSDP中专门实现的函数效率高。

# %% [markdown]
# ### 参考文献
#
# 上面的实现只对应了SDP的一种求解方法，而且仅包括了最基本的技术。关于更多提高计算效率的技术，感兴趣的读者可以参考以下文章：
# * 对不等式约束$B(X) \succeq b$的考虑：Helmberg, C., Rendl, F., Vanderbei, R. J., & Wolkowicz, H. (1996). An interior-point method for semidefinite programming. SIAM Journal on Optimization, 6(2), 342-361.
# * 利用预估-校正(predictor-corrector)技术提高内点法迭代效率：Borchers, B. (1999). CSDP, A C library for semidefinite programming. Optimization methods and Software, 11(1-4), 613-623.
# * 将问题转化为自对偶形式(self-dual)来更好地判断解的不可行性：Domahidi, A., Chu, E., & Boyd, S. (2013, July). ECOS: An SOCP solver for embedded systems. In 2013 European Control Conference (ECC) (pp. 3071-3076). IEEE.
